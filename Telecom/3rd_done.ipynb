# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
#
# **Привет!**
#
# Меня зовут Алексей Манелюк, я буду проверять твой проект. Предлагаю общаться на "ты" 😉, но если неудобно - скажи и будем на "вы".
#
# Моя основная цель - не указать на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать крутым аналитиком данных. Тобой проделана большая работа над проектом,
# но давай сделаем его еще лучше. В тексте проекта ты увидишь мои комментарии, пожалуйста не удаляй и не изменяй их. У комментариев могут быть приписки **V2**, **V3** и т.д., которые соответствуют версии проверки. Я буду использовать цветовую разметку:
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Так выделены самые важные замечания. Без их отработки я не смогу принять проект. </div>
#
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Так выделены небольшие замечания. Не более трёх таких замечаний допустимы. Если их много - постарайся исправить их.</div>
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Так выделены все остальные комментарии.</div>
#
# Предлагаю работать в диалоге: если что-то дорабатываешь или отвечаешь на мой комментарий - пиши об этом и мне будет удобней, если ты выделишь свои комментарии:
# <p>
# <div class="alert-info">
# <b>Комментарий студента</b>
#
# Например, так.</div>
#
# Все это поможет мне быстрее принять твой проект.</div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Название-столбцов" data-toc-modified-id="Название-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Название столбцов</a></span></li><li><span><a href="#Заполнение-пропусков" data-toc-modified-id="Заполнение-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заполнение пропусков</a></span><ul class="toc-item"><li><span><a href="#Общий-случай" data-toc-modified-id="Общий-случай-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Общий случай</a></span></li><li><span><a href="#Апартаменты-и-высота-потолков" data-toc-modified-id="Апартаменты-и-высота-потолков-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Апартаменты и высота потолков</a></span></li><li><span><a href="#Площадь-квартир" data-toc-modified-id="Площадь-квартир-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Площадь квартир</a></span></li><li><span><a href="#Расстояние" data-toc-modified-id="Расстояние-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Расстояние</a></span></li></ul></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Стоимость-за-кв.метр" data-toc-modified-id="Стоимость-за-кв.метр-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Стоимость за кв.метр</a></span></li><li><span><a href="#Дата-объявления" data-toc-modified-id="Дата-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Дата объявления</a></span></li><li><span><a href="#Этаж-квартиры" data-toc-modified-id="Этаж-квартиры-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры</a></span></li><li><span><a href="#Соотношение-площадей" data-toc-modified-id="Соотношение-площадей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Соотношение площадей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Построение-гистограмм" data-toc-modified-id="Построение-гистограмм-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Построение гистограмм</a></span></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры</a></span></li><li><span><a href="#Редкие-и-выбивающиеся-значения" data-toc-modified-id="Редкие-и-выбивающиеся-значения-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Редкие и выбивающиеся значения</a></span></li><li><span><a href="#Факторы-стоимости-квартиры" data-toc-modified-id="Факторы-стоимости-квартиры-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Факторы стоимости квартиры</a></span></li><li><span><a href="#Топ-10-населенных-пунктов" data-toc-modified-id="Топ-10-населенных-пунктов-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Топ 10 населенных пунктов</a></span></li><li><span><a href="#Квартиры-в-Санкт-Петербурге" data-toc-modified-id="Квартиры-в-Санкт-Петербурге-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Квартиры в Санкт-Петербурге</a></span></li><li><span><a href="#Сегмент-квартир-в-центре" data-toc-modified-id="Сегмент-квартир-в-центре-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Сегмент квартир в центре</a></span><ul class="toc-item"><li><span><a href="#Распределение-значений" data-toc-modified-id="Распределение-значений-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Распределение значений</a></span></li><li><span><a href="#Факторы-стоимости" data-toc-modified-id="Факторы-стоимости-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Факторы стоимости</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# **Цель исследования** - Нужно научиться определять рыночную стоимость объектов недвижимости. Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# **Ход исследования**
# Входные данные — архив объявлений сервиса Яндекc Недвижимость. О качестве данных ничего не известно. Поэтому перед проверкой гипотезы понадобится обзор данных.
# Необходимо проверить данные на ошибки и оценить их влияние на исследование. Затем, на этапе предобработки нужно поискать возможность исправить самые критичные ошибки данных.
# Таким образом, исследование пройдёт в три этапа:
#  1. Обзор данных.
#  2. Предобработка данных.
#  3. Установить параметры для автоматизированной системы.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Отлично что во вступлении пишешь бриф, цели исследования, план работы. 👍</div>

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Откроем таблицу и изучим общую информацию о данных. Прочитаем файл data.csv и сохраним его в переменной `df`:

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('/datasets/real_estate_data.csv') # read file and save in df

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Хорошая практика сразу грузить нужные библиотеки. А также загружать библиотеки и файлы отдельными блоками.
#
# Также могу посоветовать называть датафреймы и переменными именами, которые отражают какие данные они содержат. В данном случае подошло бы `flats`.</div>
#
# <div class="alert-info">
# <b>Комментарий студента</b>
#
# Привет, Алексей!
#
# Спасибо! Учту в будующих проектах.
# </div>

# %% [markdown]
# Выведем на экран первые пять строк таблицы.

# %%
df.head() # output top 5 strings
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %% [markdown]
# Данные склеились в одну строку вместо того, чтобы разбиться по колонкам. Это произошло из-за разделителей в формате. Прочитаем файл повторно, указав в качестве разделителя знак табуляции `\t`, и сохраним результат в датафрейме.

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') # read file with separator and save in df
df.head() # output top 5 strings
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Общая информация о таблице:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Итак, в таблице 22 столбца. Согласно документации к данным:
#
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * cityCenters_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * first_day_exposition — дата публикации
# * floor — этаж
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * last_price — цена на момент снятия с публикации
# * living_area — жилая площадь в квадратных метрах (м²)
# * locality_name — название населённого пункта
# * open_plan — свободная планировка (булев тип)
# * parks_around3000 — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around3000 — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)
# * rooms — число комнат
# * studio — квартира-студия (булев тип)
# * total_area — площадь квартиры в квадратных метрах (м²)
# * total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Данные загружены верно, получена первая общая информация о датасете. 🚀</div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Количество значений в столбцах различается. Значит, в данных есть пропущенные значения.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Имеет смысл писать более подробный вывод в конце каждого шага - что сделано и зачем, какие результаты получены.
#
# </div>
#
# <div class="alert-info">
# <b>Комментарий студента</b>
#
# Спасибо за твои комментарии. Исправлю проект далее.
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Название столбцов

# %% [markdown]
# Исправим название столбцов, используя "змеиный регистр".

# %%
# rename columns
df = df.rename(columns={
        'cityCenters_nearest':'city_centers_nearest', 
        'parks_around3000':'parks_around_3000', 
        'ponds_around3000':'ponds_around_3000'
    })

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Более простое приведение названий к нижнему регистру `df.columns = df.columns.str.lower()`</div>

# %% [markdown]
# ### Заполнение пропусков

# %% [markdown]
# #### Общий случай

# %% [markdown]
# Найдем долю пропусков в каждом столбце.

# %%
df.isna().mean() # count of 'NaN'
# Out:
# total_images            0.000000
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.387991
# floors_total            0.003629
# living_area             0.080299
# floor                   0.000000
# is_apartment            0.882906
# studio                  0.000000
# open_plan               0.000000
# kitchen_area            0.096122
# balcony                 0.486054
# locality_name           0.002068
# airports_nearest        0.233850
# city_centers_nearest    0.232879
# parks_around_3000       0.232837
# parks_nearest           0.659100
# ponds_around_3000       0.232837
# ponds_nearest           0.615596
# days_exposition         0.134225
# dtype: float64

# %% [markdown]
# Удалим строки с пропусками в `floors_total, locality_name` их доля составляет всего 0,6%.

# %%
df = df.dropna(subset=['floors_total', 'locality_name']) # delete strings

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Это верное решение - удалить пропуски, если их количество не велико. Для наглядности, можно вывести инфо как изменился размер нашего датафрейма после преобразований.</div>

# %% [markdown]
# Пропуски в столбцах `'is_apartment', 'balcony', 'days_exposition', 'ceiling_height', 'parks_around_3000', 'ponds_around_3000', 'parks_nearest', 'ponds_nearest', city_centers_nearest` составляют от 8% до 88%. Строки с такими данными могут повлиять на исследование. Сложно провести оценку и заполнить пропуски медианой или средним значением, т.к. эти столбцы прямо не зависят от данных в других столбцах. Оставим пропуски в столбцах.

# %% [markdown]
# #### Апартаменты и высота потолков

# %% [markdown]
# Посмотрим какие значения принимает столбец `is_apartment`.

# %%
df['is_apartment'].value_counts(dropna=False)
# Out:
# NaN      20805
# False     2710
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Апартаменты не очень частое явление. Скорее всего столбец не заполняли для обычных квартир. Пропуск указывает на значение False. Заполним столбец соотвественно.

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# Обратимся к столбцу `ceiling_height`. Логично, что высота потолков зависит в общем случае от этажности дома. Сгруппируем данные по этажности и возьмем медиану от каждой группы.

# %%
# grouping data of floors_total and ceiling_height median
df.groupby('floors_total').agg({'ceiling_height': ['count', 'median']}).head()
# Out:
#              ceiling_height
#                       count median
# floors_total
# 1.0                      10   2.80
# 2.0                     213   2.70
# 3.0                     399   2.80
# 4.0                     787   3.00
# 5.0                    3662   2.55

# %% [markdown]
# Значения выглядят реалистичными. Заполним пропуски медианными значениями. Проверим результат.

# %%
# filling NaN with median
df['ceiling_height'] = df['ceiling_height'].fillna(df.groupby('floors_total')['ceiling_height'].transform("median"))

df[df['ceiling_height'].isna()] # checking NaN
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11575             9   9900000.0       101.0  2016-04-28T00:00:00      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 11575             NaN          33.0         53.0     32         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 11575          21.0      0.0  Санкт-Петербург           18732.0
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 11575              20444.0                0.0            NaN
#
#        ponds_around_3000  ponds_nearest  days_exposition
# 11575                3.0           80.0             53.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Всего одна квартира расположена на 33 этаже. Заполним этот пропуск медианным значением по столбцу `ceiling_height`.

# %%
# filling NaN with median
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>>
#
# У меня вызывает вопрос замена пропусков в высоте потолка и столбце `is_apartment` - подумай может есть более оптимальные пути? </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Да, скорее всего где были пропуски - там не аппартаменты.</div>

# %% [markdown]
# #### Площадь квартир

# %% [markdown]
# Обратим внимание на столбцы `living_area и kitchen_area`. Пропуски этих данных логично заполнить средними значениями в такой же пропорции от общей площади `total_area`, как это представлено в общей таблице.
#
# Выполним подсчет жилой и площади для кухни через переменные `living_ratio и kitchen_ratio`, как коэффициенты пропорций. Определим для этих переменных средние и медианные значения.

# %%
living_ratio = df['living_area'] / df['total_area'] # divide overall area on living area

# %%
coef_living = living_ratio.mean() # average value of living_ratio

# %%
kitchen_ratio = df['kitchen_area'] / df['total_area']  # divide overall area on kitchen area

# %%
coef_kitchen = kitchen_ratio.mean() # average value of kitchen_ratio

# %% [markdown]
# Примем средние значения коэффициентов пропорции для расчета жилой и площади для кухни.

# %%
# filling NaN with ratio of total area
df['living_area'] = df['living_area'].fillna(df['total_area']*coef_living) 
df['kitchen_area'] = df['kitchen_area'].fillna(df['total_area']*coef_kitchen)

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Решение верное, но такой хардкодинг лучше в работе не использовать, целесообразней присвоить эти значения переменным. Представь, если исходник поменяется - то расчет будет некорректным.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил
# </div>

# %% [markdown]
# #### Расстояние

# %% [markdown]
# Обратим внимание на столбцы `airports_nearest` и `city_centers_nearest`. Пропуски расстояний заполним медианными значениями по населенным пунктам. Медиана будет сглаживать разброс данных, особенно в случае большого города. Сгруппируем показатели расстояний по названию населенных пунктах методом `groupby()` и найдем медиану для каждой группы.
#
# Проверим результат, найдем долю пропусков по столбцу.

# %%
df['airports_nearest'] = df['airports_nearest'].fillna(df.groupby('locality_name')['airports_nearest'].transform("median")) # filling NaN with median of group by locality name
df['airports_nearest'].isna().mean() # checking count of 'NaN'
# Out:
# 0.23051135158073413

# %%
df['city_centers_nearest'] = df['city_centers_nearest'].fillna(df.groupby('locality_name')['city_centers_nearest'].transform("median")) # filling NaN with median of group by locality name
df['city_centers_nearest'].isna().mean() # checking count of 'NaN'
# Out:
# 0.23051135158073413

# %% [markdown]
# Cтолбцы заполнились только на 0,2%. Расстояния указаны не для всех населенных пунктов в данных. Оставим пропуски в данных.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Да, можно и так, а можно оставить как есть пропуски в этих столбцах.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил. оставил НаН
# </div>

# %% [markdown]
# Проверим результат, найдем долю пропусков для общих данных.

# %%
df.isna().mean() # checking count of 'NaN'
# Out:
# total_images            0.000000
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.000000
# floors_total            0.000000
# living_area             0.000000
# floor                   0.000000
# is_apartment            0.000000
# studio                  0.000000
# open_plan               0.000000
# kitchen_area            0.000000
# balcony                 0.486951
# locality_name           0.000000
# airports_nearest        0.230511
# city_centers_nearest    0.230511
# parks_around_3000       0.233397
# parks_nearest           0.659240
# ponds_around_3000       0.233397
# ponds_nearest           0.616550
# days_exposition         0.134564
# dtype: float64

# %% [markdown]
# Такое количество ошибок в общей таблице обусловлено методами получения информации (либо указаны пользователем, либо автоматически вписаны на основе картографических данных). Также ошибки могли появится из-за технической проблемы при переносе данных.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# По заданию нужно указать причины, которые могли привести к пропускам в данных. Какое твое мнение?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> перенес вывод из раздела 2.4
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Правильно - либо человеческий фактор, либо технический. 🙂</div>

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Данные из столбца `first_day_exposition` указали в часовом поясе UTC+0, в формате ISO. Рассчитаем число, месяц и год публикации объявления, результат добавим в новую колонку.

# %%
df['date'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%d')

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Это все преобразования типов, которые можно сделать на данном этапе?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
#
# - Добавил столбец для даты. Перенес код из п.3.2. Моя структура не совпадала с заданием.
#
#
# - Подскажи, пожалуйста, как выполнить перевод столбца с числами и с Нан в класс integer? пробовал несколько вариантов, но работает только метод .astype('Int64'). но после него, некоторые методы выдают ошибку при дальнейшей работе.
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Дело в том, что с точки зрения Пандас NaN - это специальное значение типа float64. Поэтому перевод в Int возможен только тех столбцов, которые не содержат NaN. </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Предобработка обнаружила следующие проблемы в данных:
#
# - названия столбцов,
# - пропущенные значения,
# - некорректный тип данных
#
# Название столбцов записали с помощью "змеиного регистра".
#
# Пропущенные значения в столбцах `living_area и kitchen_area` мы заменили на расчетные пропорционально общей площади для каждого объекта недвижимости. Пропуски для `airports_nearest` заполнили медианой расстояний по названию населенного пункта, где это было возможно. Медиана "сглаживает" разброс в количественных переменных, ее показатели ближе к общему числу значений, нежели к минимальному/максимальному.
#
# Отредактировали тип данных для столбца с датой.
#
# Количество объявлений уменьшилось до 23565, т.е. сократилось на 0,6% после исправления данных.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Правильно, что пишешь краткий вывод в конце шага!</div>

# %%
df.shape[0] # count of strings in updated data
# Out:
# 23565

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Стоимость за кв.метр

# %% [markdown]
# В таблице имеется общая стоимость объектов недвижимости, но не указана цена за квадратный метр. Добавим такой столбец для анализа параметров в нашем исследовании.
#
# Разделим данные столбца `last_price` на `total_area`, полученные значения запишем в колонку `price_meter`. Округлим результаты до целых чисел. Выведем 5 первых строк для проверки расчета.

# %%
df['price_meter'] = df['last_price'] / df['total_area'] # divide realty price on total area
df['price_meter'] = df['price_meter'].astype(int) # transfer to integer
df.head() # top 5 strings
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0    51.000000      8         False  ...
# 1            2.75          11.0    18.600000      1         False  ...
# 2            2.55           5.0    34.300000      4         False  ...
# 3            2.60          14.0    89.825011      9         False  ...
# 4            3.03          14.0    32.000000     13         False  ...
#
#      locality_name  airports_nearest  city_centers_nearest  parks_around_3000  \
# ...

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Цена квадратного метра посчитана правильно.</div>

# %% [markdown]
# ### Дата объявления

# %% [markdown]
# Рассчитаем день недели, месяц и год публикации объявления. Результаты запишем в новые колонки `weekday`, `month` и `year` соответственно. Укажем в них месяц и год с помощью `DatetimeIndex`, а день недели методом `dt.weekday`.

# %%
# new columns with weekday, month and year

df['weekday'] = df['date'].dt.weekday
df['month'] = pd.DatetimeIndex(df['date']).month
df['year'] = pd.DatetimeIndex(df['date']).year

df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0    51.000000      8         False  ...
# 1            2.75          11.0    18.600000      1         False  ...
# 2            2.55           5.0    34.300000      4         False  ...
# 3            2.60          14.0    89.825011      9         False  ...
# 4            3.03          14.0    32.000000     13         False  ...
#
#    parks_around_3000  parks_nearest  ponds_around_3000  ponds_nearest  \
# ...

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# По заданию нужно добавить также месяц и год публикации объявления. </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Перенес код из п.4.4 (месяц, год). Моя структура не совпадала с заданием.
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Теперь верно!</div>

# %% [markdown]
# ### Этаж квартиры

# %% [markdown]
# Проведем категоризацию значений из столбца `floors_total`. Добавим столбец `floor_cat` для значений `первый, последний, другой`. Данный метод поможет, к примеру, выявить зависимость между этажом и стоимостью недвижимости или применить фильтрацию.
#
# Создадим функцию, которая проверит значения "этаж" и передаст результат в `floor_cat`.

# %%
def floor_cat(row):   # function to define category
    if row['floor'] == 1:
        floor_cat = 'первый'
    elif row['floor'] == row['floors_total']:
        floor_cat = 'последний'
    else:
        floor_cat = 'другой'
    return floor_cat

df['floor_cat'] = df.apply(floor_cat, axis=1) # apply function

df.head() # top 5 strings
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0    51.000000      8         False  ...
# 1            2.75          11.0    18.600000      1         False  ...
# 2            2.55           5.0    34.300000      4         False  ...
# 3            2.60          14.0    89.825011      9         False  ...
# 4            3.03          14.0    32.000000     13         False  ...
#
#    parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# Функция выполнила категоризацию корректно.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Категоризация этажности проведена верно! Молодец, что сделал через функцию.</div>

# %% [markdown]
# ### Соотношение площадей

# %% [markdown]
# Найдем соотношение жилой и общей площади, а также отношение площади кухни к общей для каждого объекта недвижимости. Результаты поместим в столбцы `living_area_ratio` и `kitchen_area_ratio`. Выведем пять первых строк для проверки.

# %%
df['living_area_ratio'] = df['living_area'] / df['total_area'] # divide overall area on living area
df['kitchen_area_ratio'] = df['kitchen_area'] / df['total_area'] # divide overall area on kitchen area
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0    51.000000      8         False  ...
# 1            2.75          11.0    18.600000      1         False  ...
# 2            2.55           5.0    34.300000      4         False  ...
# 3            2.60          14.0    89.825011      9         False  ...
# 4            3.03          14.0    32.000000     13         False  ...
#
#    ponds_nearest  days_exposition       date  price_meter weekday  month  \
# ...

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Соотношение площадей рассчитано верно.</div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Предоставленные данные по объектам недвижимости требовали доработки. Для определения параметров будущей автоматизированной системы мы сделали следующие шаги и добавили данные для каждого объекта недвижимости:
#
# - стоимость за кв.метр;
# - дата объявления (день недели, месяц, год);
# - категорию по этажности;
# - соотношение площадей.
#
# Данные изменения позволят нам найти и исследовать зависимости в общих данных. Рассмотрим подробнее необходимые параметры в разделе 4.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Построение гистограмм

# %% [markdown]
# **Площадь**
#
# Построим гистограмму для данных из соответствующего столбца.

# %%
df['total_area'].hist(range=(0,400), bins=100); # histogram for total area

# %% [markdown]
# Гистограмма показывает, что большая часть квартир имеет площадь от 30 до 70 кв.м. Распределение значений похоже на нормальное.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Чтобы избавиться от этой строки
#
# `<matplotlib.axes._subplots.AxesSubplot at 0x7fcface4ef10>`
#
# нужно дописать `plt.show()` в конце ячейки кода вывода графика.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо! а еще можно ";" после кода. непротив?
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# 👍</div>

# %% [markdown]
# **Цена за кв.метр**
#
# Построим гистограмму для данных из соответствующего столбца.

# %%
df['price_meter'].hist(range=(0,500000), bins=200); # histogram for price_meter

# %% [markdown]
# Средняя стоимость недвижимости указана в районе 100000 за кв.метр. Распределение значений похоже на нормальное. Необходимо рассмотреть значения по цене в случаях конкретного населенного пункта для более точного анализа. Сделаем такое исследование в следующем разделе.

# %% [markdown]
# **Число комнат**
#
# Построим гистограмму для данных из соответствующего столбца.

# %%
df['rooms'].hist(range=(0,16), bins=50); # histogram for rooms

# %% [markdown]
# Число комнат для некоторых квартир не указано, содержит "0". Средние значения от 1 до 3 преобладают.

# %% [markdown]
# **Высота потолков**
#
# Построим гистограмму для данных из соответствующего столбца.

# %%
df['ceiling_height'].hist(range=(0,5), bins=100); # histogram for ceiling_height

# %% [markdown]
# Распределение значений похоже на нормальное. Средняя высота потолков от 2.5 до 3 метров.

# %% [markdown]
# ### Время продажи квартиры

# %% [markdown]
# Построим гистограмму для данных из соответствующего столбца.

# %%
df['days_exposition'].hist(range=(0, 1300), bins=200); # histogram for days_exposition

# %% [markdown]
# Большая часть значений распределена в зоне до 200 дней. Рассмотрим эту гистограмму подробнее.

# %%
df['days_exposition'].hist(range=(0, 200), bins=200); # histogram for days_exposition within range=(0, 200)

# %% [markdown]
# На графике выделяются два пика. Скорее всего объявления размещались на фиксированный срок (примерно 40 или 60 дней), по истечении которого объявление с сайта снимается. Эти всплески - самые популярные сроки размещения, возможно на этот период были акции или специальные предложения на сайте. Вряд ли эти значения говорят о реальных сроках продажи.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# А что можно сказать о пиковых значениях? Их тут по меньшей мере два.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавил вывод
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Да, скорее всего - автоматическое снятие.</div>

# %% [markdown]
# Найдем среднее и медианные значения. Посмотрим распределение методом describe.

# %%
df['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Медиана `95` примерно в двое меньше среднего значения `180`. В данных имеются объявления, когда недвижимость продавалась долго (больше года), это выбросы, которые влияют на показатели среднего срока. Обычно продажа занимает от 95 до 180 дней. Очень быстро квартиры продавались в течение недели, а необычно долго более 400 дней (`mean + std`).

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Гистограммы построены и прокомментированы верно.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> добавил describe и Обновил вывод
# </div>

# %% [markdown]
# ### Редкие и выбивающиеся значения

# %% [markdown]
# Проведем анализ особенностей объявлений по продаже недвижимости. Отфильтруем общие данные от редких и выбивающихся значений. Результаты запишем в новый датасет `df_filter`.

# %% [markdown]
# **Время продажи квартиры**
#
# Рассмотрим гистограмму из раздела 4.2. Время продажи продолжительностью 400 дней — уже редки, дольше 400 дней почти не продаются. Примем верхнюю границу в 400 дней. Это число кажется разумным: дольше продаются редко.

# %%
df_filter = df.query('days_exposition <= 400') # remove values of days_exposition more than 400 days

# %% [markdown]
# **Высота потолков**
#
# Рассмотрим гистограмму из раздела 4.1. Квартиры с высотой потолков из диапазонов менее 2.5 и более 3.5 метров — уже редки, гистограмма на этом участке сливается с нулём. Примем границы от 2.5 до 3.5 метров.

# %%
df_filter = df_filter.query('2.5 <= ceiling_height <= 3.5') # remove values of ceiling_height more than 3.5 meters

# %% [markdown]
# **Число комнат**
#
# Рассмотрим гистограмму из раздела 4.1. Квартиры с числом комнат из диапазонов менее 1 и более 4 — уже редки. Примем границы от 1 до 4 комнат.

# %%
df_filter = df_filter.query('1 <= rooms <= 4') # remove values of rooms more than 4

# %% [markdown]
# **Цена за кв.метр**
#
# Рассмотрим гистограмму из раздела 4.1. Стоимость квадратного метра из диапазонов менее 50000 и более 150000 — уже редкость. Примем границы от 50 до 150 тысяч.

# %%
df_filter = df_filter.query('50000 <= price_meter <= 150000') # remove values more than 200000

# %% [markdown]
# **Площадь**
#
# Рассмотрим гистограмму из раздела 4.1. Площадь объектов недвижимости из диапазонов менее 30 и более 100 — уже редкость. Примем границы от 30 до 100 кв. м.

# %%
df_filter = df_filter.query('30 <= total_area <= 100') # remove values of total_area more than 130

# %% [markdown]
# Количество объявлений уменьшилось до 14163, т.е. сократилось на 40% в результате выборки исходных данных.

# %%
df_filter.shape[0] # count of strings in updated data
# Out:
# 14163

# %% [markdown]
# По итогам анализа в данном шаге можно сформулировать портрет среднестатистической квартиры выставленной на продажу:
# - время продажи до 400 дней;
# - высота потолков от 2.5 до 3.5 м;
# - число комнат от 1 до 4;
# - стоимость от 50000 до 150000 за кв.м;
# - площадь от 30 до 100 кв.м.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# По итогам анализа в данном шаге можно сформулировать портрет среднестатистической квартиры выставленной на продажу?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
#
# - Добавил вывод
#
# - добавил новый датасет **df_filter**
#
# - обновил фильтры по всем параметрам. сделал выборку жестче
# </div>

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера V2 ⚠️</b>
#
# Параметры сформулированы слишком общо. Можно было посмотреть медианы или моды, чтобы составить портрет типичной квартиры.</div>

# %% [markdown]
# ### Факторы стоимости квартиры

# %% [markdown]
# **Площадь**
#
# Рассмотрим зависимость параметров площади на стоимость объектов недвижимости. Построим диаграмму рассеивания и вычислим коэффициент корреляции Пирсона для этих параметров.

# %%
df_filter.plot(x='total_area', y='last_price', kind='scatter', grid=True, alpha=0.1); # scatter plot for price with area

# %%
df_filter['last_price'].corr(df_filter['total_area']) # correlation coefficient
# Out:
# 0.7864219272730709

# %% [markdown]
# Диаграмма иллюстрирует прямую зависимость стоимости от площади для объектов недвижимости в средних значениях. С увеличением площади квартир увеличивается их цена. Коэффициент корреляции также подтверждает наличии связи этих параметров.

# %% [markdown]
# **Число комнат**
#
# Рассмотрим зависимость числа комнат на стоимость объектов недвижимости. Построим диаграмму рассеивания для этих параметров.

# %%
df_filter.plot(x='rooms', y='last_price', kind='scatter', grid=True, alpha=0.1); # scatter plot for price with rooms

# %% [markdown]
# Диаграмма не показывает явной зависимости. Построим диаграмму размаха и посмотрим на распределения медианных значений. Вызовем библиотеку `seaborn`.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Да, ты прав - совершенно не информативно. Для выявления взаимосвязей в таких случаях лучше рассматривать медианные значения. </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> изменения не требуются
# </div>

# %%
sns.boxplot(x="rooms", y="last_price", data=df_filter, showfliers=False); # boxplot for price with rooms

# %% [markdown]
# Диаграмма размаха иллюстрирует прямую зависимость стоимости от количества комнат для объектов недвижимости. С увеличением количества комнат квартир увеличиваются медианные значения.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Да, можно так.</div>

# %% [markdown]
# **Удалённость от центра**
#
# Рассмотрим зависимость расстояния от центра на стоимость для объектов недвижимости. Построим диаграмму рассеивания и вычислим коэффициент корреляции Пирсона для этих параметров.

# %%
# scatter plot for last_price with city_centers_nearest
df_filter.plot(x='city_centers_nearest', y='last_price', kind='scatter', grid=True, alpha=0.1);

# %%
df_filter['city_centers_nearest'].corr(df_filter['last_price']) # correlation coefficient
# Out:
# -0.3299300863321365

# %% [markdown]
# Корреляция низкая, но на диаграмме можно заметить: чем ближе к центру, тем больше концентрация высоких цен на квартиры. Необходимо визуализировать зависимость более отчетливо.
#
# Сгруппируем данные по расстоянию и найдем медиану для каждой группы. Построим график по результатам группировки.

# %%
# breakdown of city_centers_nearest for 20 groups (column with group categories)
df_filter.loc[:, 'center_group'] = pd.qcut(df_filter['city_centers_nearest'],20)

# group of center_group and last_price
df_filter.groupby('center_group')['last_price'].agg(['count','median'])
# Out:
#                     count     median
# center_group
# (328.999, 4759.8]     579  7100000.0
# (4759.8, 6985.2]      579  6500000.0
# (6985.2, 8952.3]      579  5900000.0
# (8952.3, 10251.0]     585  4750000.0
# (10251.0, 11049.0]    574  4690000.0
# (11049.0, 11689.0]    580  4822500.0
# (11689.0, 12166.0]    578  4750000.0
# (12166.0, 12689.2]    578  4800000.0
# (12689.2, 13266.2]    579  4990000.0
# (13266.2, 13875.0]    581  4800000.0
# (13875.0, 14513.9]    576  4700000.0
# (14513.9, 14950.8]    579  4690000.0
# (14950.8, 15522.0]    580  4700000.0
# (15522.0, 16088.0]    579  4600000.0
# (16088.0, 16799.0]    578  4465000.0
# (16799.0, 18049.2]    579  4450000.0
# (18049.2, 21403.0]    581  4167000.0
# (21403.0, 27984.6]    577  4100000.0
# (27984.6, 32230.3]    579  3700000.0
# (32230.3, 64857.0]    579  3850000.0

# %%
# plot of city_centers_nearest and last price
df_filter.groupby('center_group')['last_price'].median().plot(figsize=(16,9));

# %% [markdown]
# График в общем случае показывает зависимость: чем дальше объекты недвижимости находятся от центра, тем ниже в среднем их стоимость.

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Такое решение также не выглядит оптимальным - подумай как можно четче выразить зависимость цену от расстояния до центра? </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Теперь стало наглядней! 👍 Как ты определишь теперь границу центра?</div>

# %% [markdown]
# **Этаж**
#
# Рассмотрим зависимость категории этажа `floor_cat` на стоимость объектов недвижимости. Построим диаграмму размаха для этих параметров. Воспользуемся методом `boxplot`.

# %%
# boxplot for last_price with floor_cat

sns.boxplot(x="floor_cat", y="last_price", data=df_filter,  showfliers=False); # boxplot for price with rooms;

# %% [markdown]
# В общем случае медиана показывает, что высокие цены на недвижимость в категории "другой", затем в категории "последний", а на первом этаже квартире дешевле.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Здесь также целесообразно рассмотреть медианную цену в зависимости от этажности.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Так стало понятней.</div>

# %% [markdown]
# **День недели**
#
# Рассмотрим зависимость даты размещения (день недели) на стоимость для объектов недвижимости. Построим диаграмму размаха для этих параметров. Воспользуемся методом `boxplot`.

# %%
sns.boxplot(x="weekday", y="last_price", data=df_filter, showfliers=False) # boxplot for weekday and price_meter
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='last_price'>

# %% [markdown]
# Распределение значений по каждому дню недели примерно одинаковый. День недели не влияет на стоимость.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# По такому графику все выглядит одинаково. 🙂</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> согласен
# </div>

# %% [markdown]
# **Месяц, год**
#
# Рассмотрим зависимость даты размещения (месяц, год) на стоимость для объектов недвижимости. Добавим столбцы `month` и `year`, укажем в них соответственно месяц и год с помощью `DatetimeIndex`.
#
# Построим диаграмму размаха для этих параметров. Воспользуемся методом `boxplot`.

# %%
sns.boxplot(x="month", y="last_price", data=df_filter, showfliers=False); # boxplot for month and price

# %% [markdown]
# Прямой зависимости от месяца не обнаружено, медианные значения примерно одинаковые по месяцам.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Для более наглядного отображения здесь тоже можно использовать подход как я писал выше.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> медиана показывает, что зависимости нет. подскажи, что изменить?
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Я имел в виду такой график. 👇 На нем видно, что медианная цена немного ниже в марте, мае и июне.</div>

# %%
#Код ревьюера
import matplotlib.pyplot as plt

df_filter.groupby('month')['last_price'].median()\
    .plot(kind = 'bar')
plt.show()

# %%
sns.boxplot(x="year", y="last_price", data=df_filter, showfliers=False); # boxplot for year and price

# %% [markdown]
# Прямой зависимости от года не обнаружено, значения распределяются волнообразно. Самые высокие цены на квартиры были в 2015. Наблюдается тенденция - падение стоимости до 2017 года, а затем рост средних цен на недвижимость.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Здесь виден тренд.</div>

# %% [markdown]
# **Вывод**
#
# Наше исследование показывает, что на стоимость объектов недвижимости напрямую влияют: площадь, число комнат и расстояние до центра. Самые дорогие квартиры в общем случае имеют параметры:  расположены в центре на этажах кроме первого и последнего, площадь более 100 кв.м, число комнат от 4х, объявления размещены до 2016 года.

# %% [markdown]
# ### Топ 10 населенных пунктов

# %% [markdown]
# Выберем 10 населённых пунктов с наибольшим числом объявлений. Создадим словарь `name` с названием таких пунктов. Воспользуемся методом `value_counts` для выборки нужных объявлений из общих данных.

# %%
name = df_filter['locality_name'].value_counts().head(10) # creating vocabulary 'locality_name' of top 10 of ads 
name
# Out:
# Санкт-Петербург      9770
# посёлок Мурино        409
# посёлок Шушары        345
# Колпино               269
# Всеволожск            263
# посёлок Парголово     258
# Пушкин                235
# деревня Кудрово       229
# Гатчина               218
# Петергоф              145
# Name: locality_name, dtype: int64

# %% [markdown]
# Выполним срез общих данных по индексам из полученного словаря. Результаты запишем в новый датасет `top`. Посчитаем среднюю цену квадратного метра в этих населённых пунктах.

# %%
# query of data in 'name', mean of result

top = df_filter.query('locality_name in @name.index')
top.pivot_table(index='locality_name', values='price_meter').sort_values(by='price_meter', ascending=False)
# Out:
#                      price_meter
# locality_name
# Санкт-Петербург    102364.106346
# Пушкин              98485.582979
# деревня Кудрово     91948.165939
# посёлок Парголово   89608.852713
# посёлок Мурино      84929.506112
# Петергоф            83076.482759
# посёлок Шушары      77320.513043
# Колпино             74608.297398
# Гатчина             69527.270642
# Всеволожск          67979.638783

# %% [markdown]
# Список для 10 населённых пунктов с наибольшим числом объявлений показывает, что самая высокая стоимость кв.метра в Санкт-Петербурге, а самая низкая во Всеволожске.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Этот шаг работы выполнен верно.</div>

# %% [markdown]
# ### Квартиры в Санкт-Петербурге

# %% [markdown]
# Рассмотрим подробнее объекты недвижимости из Санкт-Петербурга, таких объявлений у нас получилось больше всего в данных (доля 69%). Определим, где в городе находится центральная зона, там стоимость недвижимости должна быть сравнительно высокой.
#
# Выполним срез общих данных по названию города, результат запишем в новый датасет `spb`.

# %%
# share of St.Peterburg data in df_filter

len(df_filter.query('locality_name=="Санкт-Петербург"'))/len(df_filter)
# Out:
# 0.689825601920497

# %%
# query of data for St.Peterburg
    
spb = df_filter.query('locality_name=="Санкт-Петербург"').copy()

# %% [markdown]
# Добавим столбец `km` c округлением данных из колонки `city_centers_nearest` до километров (целые чиисла).

# %%
# columns 'spb' with values of km

spb['km'] = spb['city_centers_nearest']/1000 
spb['km'] = spb['km'].astype(int)

# %% [markdown]
# Рассчитаем стоимость каждого километра от центра для всех объявлений. Разделим колонку `price_meter` на `km`.  Результаты запишем в новый столбец `price_km` с округлением до целого. Создадим функцию `price_km`, которая проведет данные вычисления с поправкой, если значения столбца `km` равно нулю, то в столбец просто вносим числа из `price_meter` без деления, т.к. на ноль деление невозможно.

# %%
def price_km(row):   # function for calculation of price_km
    if row['km'] == 0:
        price_km = row['price_meter']
    else:
        price_km = row['price_meter']/row['km']
    return int(price_km)

spb['price_km'] = spb.apply(price_km, axis=1) # apply function

spb.head() # top 5 strings of spb
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 4              2  10000000.0       100.0  2018-06-19T00:00:00      2
# 9             18   5400000.0        61.0  2017-02-26T00:00:00      3
# 10             5   5050000.0        39.6  2017-11-16T00:00:00      1
# 15            16   4650000.0        39.0  2017-11-18T00:00:00      1
# 16            11   6700000.0        82.0  2017-11-23T00:00:00      3
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 4             3.03          14.0         32.0     13         False  ...
# 9             2.50           9.0         43.6      7         False  ...
# 10            2.67          12.0         20.3      3         False  ...
# 15            2.60          14.0         20.5      5         False  ...
# 16            3.05           5.0         55.6      1         False  ...
#
#     price_meter  weekday  month  year floor_cat  living_area_ratio  \
# ...

# %% [markdown]
# Вычисления прошли корректно. Построим график зависимости для средних значений стоимости за каждый километр.

# %%
aver_price_spb = spb.pivot_table(index = 'km', values= 'price_km') # pivot_table for km and average price

aver_price_spb.plot(style='o-', grid=True) # plot for average price_km and km
# Out:
# <AxesSubplot:xlabel='km'>

# %% [markdown]
# Значение 5 км - это граница, где график сильно меняется, т.е. центральная зона Санкт-Петербурга. В данной зоне мы имеем самую высокую стоимость на объекты недвижимости и кривая показывает, как сильно цена зависит от удалённости от центра. Снаружи этой зоны изменение средних цен не так заметно.

# %% [markdown]
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Такое выделение центра не выглядит обоснованно. По такому графику также сложно что-то сказать. </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Так гораздо лучше.</div>

# %% [markdown]
# ### Сегмент квартир в центре

# %% [markdown]
# #### Распределение значений

# %% [markdown]
# Определим в общих данных, где в населенных пунктах находится центральная зона.
# Сгруппируем значения "расстояние до центра города" по названиям населенного пункта, найдем минимум, максимум и число объявлений. Отсортируем полученные данные по минимуму, выведем на экран топ-30 городов.

# %%
# pivot_table for locality_name and km
b = df_filter.pivot_table(index='locality_name', values='city_centers_nearest', aggfunc=['min','max', 'count'])

# %%
b.sort_values(('min', 'city_centers_nearest'), ascending=False).head(30)
# Out:
#                                          min                  max  \
#                         city_centers_nearest city_centers_nearest
# locality_name
# посёлок Молодёжное                   64857.0              64857.0
# Зеленогорск                          52628.0              62706.0
# Кронштадт                            46678.0              51511.0
# посёлок Репино                       45226.0              45226.0
# посёлок Белоостров                   38868.0              38868.0
# Ломоносов                            36816.0              61495.0
# посёлок Сапёрный                     35822.0              35892.0
# Павловск                             31533.0              36445.0
# Сестрорецк                           31130.0              42971.0
# посёлок Понтонный                    30709.0              33853.0
# Петергоф                             29815.0              49574.0
# Колпино                              29436.0              37477.0
# ...

# %% [markdown]
# Наблюдается закономерность, что у некоторых населенных пунктов столбец `city_centers_nearest` не заполнен. Санкт-Петербург имеет центральную зону в границе 5го километра. Значения расстояния не заполнены или этот пункт очень мал (путь до центра меньше 5 км), чтобы там выделить центральную зону.
#
# Объявления в центральной зоне рассмотрим только для Санкт-Петербурга (датасет `spb_center`). Построим матрицу рассеяния для датасета `spb_center` для изучения параметров: площадь, цена, число комнат, высота потолков.

# %%
# query of data for S.Peterburg center
spb_center = spb.query('km<5')
spb_center1 = spb_center[['total_area', 'price_meter', 'ceiling_height', 'rooms']].copy()

# %%
pd.plotting.scatter_matrix(spb_center1, figsize=(12, 12));

# %% [markdown]
# Средние значения для площади отличаются от общего вывода. В центральной зоне квартиры больше, показатели находятся в диапазоне от 50 до 100 кв.м.
#
# Средние значения для стоимости за кв.метр отличаются от общего вывода. В центральной зоне квартиры дороже, показатели находятся в диапазоне от 80000 до 150000.
#
# Средние значения для высоты потолков не отличаются от общего вывода. В центральной зоне эти показатели также находятся в диапазоне от 2,5 до 3,5 м.
#
# Средние значения для числа комнат немного отличаются от общего вывода. В центральной зоне эти показатели находятся в диапазоне от 2 до 3 комнат.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Молодец что вышел за рамки задания и провел дополнительный анализ!👍</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> спасибо! подскажи, как уйти от ворнинга в "b = df_filter.pivot_table..." ?
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Все предупреждения можно отключать так:
#
# `import warnings
#  warnings.filterwarnings('ignore')`</div>

# %% [markdown]
# #### Факторы стоимости

# %% [markdown]
# Построим матрицу рассеяния для датасета `spb_center` для изучения влияния на стоимость квартир таких параметров, как число комнат, этаж, удалённость от центра, дата размещения объявления.
#
# Рассмотрим зависимость стоимости от количества комнат.

# %%
sns.boxplot(x="rooms", y="last_price", data=spb_center); # boxplot for price with rooms

# %% [markdown]
# Средние значения для стоимости характером не отличаются от общего вывода. В центральной зоне стоимость квартиры тем выше, чем больше комнат.
#
# Рассмотрим параметры стоимости и расстояния до центра.

# %%
# scatter plot for price with city_centers_nearest
spb_center.plot(x='city_centers_nearest', y='last_price', kind='scatter', grid=True);

# %% [markdown]
# Стоимость квартир в центральной зоне не зависят от расстояния до центра в отличии от общего вывода. Здесь объекты недвижимости и так расположены в самой дорогой зоне и на стоимость влияют больше другие факторы. Чаще всего объявления представлены из зоны 4-5 км до центра.
#
# Рассмотрим параметры стоимости и категории этажа.

# %%
# boxplot for last_price with floor_cat
sns.boxplot(x="floor_cat", y="last_price", data=spb_center);

# %% [markdown]
# Здесь медианные значения стоимости имеют такую же зависимость, как в общих данных. Самая высокая цена, в общем случае, в категории "другой", затем в категории "последний", а на первом этаже квартире дешевле.
#
# Рассмотрим параметры стоимости и даты размещения объявления (месяц).

# %%
sns.boxplot(x="month", y="last_price", data=spb_center, showfliers=False); # boxplot for price with month

# %% [markdown]
# Прямой зависимости от месяца, как и в общем выводе, не обнаружено, значения распределяются волнообразно. Медиана показывает, что цены несколько выше были на квартиры в марте.
#
# Рассмотрим параметры стоимости и даты размещения объявления (год).

# %%
sns.boxplot(x="year", y="last_price", data=spb_center, showfliers=False); # boxplot for price with year

# %% [markdown]
# Прямой зависимости или тренда от года, как в общем выводе, не обнаружено, значения распределяются волнообразно. Но медиана показывает, что самые высокие цены на квартиры были в 2016 и 2019 году.

# %% [markdown]
# #### Вывод

# %% [markdown]
# Анализ показывает, что для объектов недвижимости из центральной зоны и для квартир из общей базы есть схожие факторы влияния на стоимость: это число комнат и категория этажа. Дата размещения также влияет на стоимость, но в центральной зоне эта зависимость распределяется по-своему. Значения расстояний до центра уже не влияют на стоимость.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# В целом, все так. По графикам - предложения как к пункту 4.4.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Отлично!</div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Исследование выявило определенные факторы, которые влияют на стоимость недвижимости. Можно выделить следующие параметры, которые определяют цену квартиры в общем случае:
# - площадь;
# - число комнат;
# - расположение на определенном этаже;
# - расстояние от центра;
# - дата размещения (год).
#
# Недвижимость в центральной зоне имеет схожие факторы, но для параметров даты размещения имеется своя зависимость. Значения расстояний до центра у таких квартир не влияют на стоимость. Группа объявлений из центральной зоны была рассмотрена только для Санкт-Петербурга. В других населенных пунктах трудно выделить подобную зону, столбец с расстояниями до центра не был заполнен в общих данных. Доля пропусков для этой колонки составила 23%. В данных представлено недостаточно значений для некоторых параметров объектов недвижимости. Доля пропусков в некоторых случаях достигает от 66% до 88%.
#
# Анализ в общем случае показывает, что для самой дорогой недвижимости в общем случае характерны следующие особенности: расположена в центре Санкт-Петербурга, число комнат больше 4, общая площадь от 120 кв.м, этаж - не 1й и не последний, выставлена на продажу в 2014 году.
#
# Хорошие варианты недвижимости в центре Санкт-Петербурга можно выгодно купить, если обратить внимание на такие особенности:
# - Следует выбирать недвижимость, которая находится в районе 5-10 км от центра. Территориально удобно и высокая вероятность низкой цены.
# - Небольшое количество комнат (1-2).
# - Расположение квартиры на первом этаже.

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Правильно, что в общий вывод погрузил выводы, полученные в предыдущих шагах работы. Можно немного расширить, добавив рекомендации потенциальному покупателю.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправил
# </div>

# %% [markdown]
# <div class="alert-success">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Хорошие рекомендации, если не смущает первый этаж! 🙂</div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера:</b>
#
# Ты проделал большую работу, но давай сделаем ее еще лучше!
#
# Есть несколько критических замечаний:
# - по добавлению дополнительных столбцов с месяцем и годом
# - по определению зависимости цены от центра
# - по определению центра СПБ
#
# Также, постарайся учесть желтые комментарии.
#
# Буду ждать твой доработанный проект.</div>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера V2</b>
#
# Ты исправил критические замечания и многое улучшил дополнительно. Теперь твой проект выглядит отлично!
#
# Успехов в дальнейшем обучении!🤝
#
# </div>
